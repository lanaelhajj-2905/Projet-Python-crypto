# %% [markdown]
# Test de features avancées pour prédiction crypto.
#
# Objectif: Comparer différentes mesures de volatilité
# - Rolling standard
# - EWMA
# - Parkinson (high-low)
# - Garman-Klass (OHLC)

# %%
# Réutilise tes données Phase 2
from src.strategy.data.loaders import load_multiple
prices = load_multiple(...)

# Ton code FeatureEngineer ici
# + Visualisations
# + Analyse corrélations features
