# %% [markdown]
# """
# Comparaison stratégies ML vs. baselines.
#
# Stratégies:
# 1. Equal-Weight (baseline)
# 2. Inverse-Vol (Phase 2)
# 3. ML Stress Gate
# 4. ML Combined (stress + direction)
#
# Backtest 2021-2025 avec coûts réels.
# """
#
# # Tableau comparatif final
# # Equity curves
# # Drawdowns
# ```
