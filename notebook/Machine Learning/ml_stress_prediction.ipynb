# %%
 Données manquantes, téléchargement depuis Binance...
Téléchargement BTCUSDT...
Sauvegardé: binance_public_data\BTCUSDT_1d.csv (1461 points)
Téléchargement ETHUSDT...
Sauvegardé: binance_public_data\ETHUSDT_1d.csv (1461 points)
Téléchargement BNBUSDT...
Sauvegardé: binance_public_data\BNBUSDT_1d.csv (1461 points)
Téléchargement SOLUSDT...
Sauvegardé: binance_public_data\SOLUSDT_1d.csv (1461 points)
Téléchargement XRPUSDT...
Sauvegardé: binance_public_data\XRPUSDT_1d.csv (1461 points)
✓ Téléchargement terminé !


================================================================================
RUNNING STRATEGY: equal_weight
================================================================================
================================================================================
PORTFOLIO STRATEGY: equal_weight
================================================================================

1. Chargement des données...
  Chargement binance_public_data/BTCUSDT_1d.csv...
  Chargement binance_public_data/ETHUSDT_1d.csv...
  Chargement binance_public_data/BNBUSDT_1d.csv...
  Chargement binance_public_data/SOLUSDT_1d.csv...
  Chargement binance_public_data/XRPUSDT_1d.csv...
Période: 2021-01-02 00:00:00 → 2024-12-31 00:00:00 (1460 jours)

2. Calcul volatilité...

4. Backtest...

================================================================================
RÉSULTATS
================================================================================
Return annualisé: 39.01%
Vol annualisée:   74.74%
Sharpe:           0.825
Max Drawdown:     -86.94%
Turnover moyen:   0.07%

================================================================================
RUNNING STRATEGY: inverse_vol
================================================================================
================================================================================
PORTFOLIO STRATEGY: inverse_vol
================================================================================

1. Chargement des données...
  Chargement binance_public_data/BTCUSDT_1d.csv...
  Chargement binance_public_data/ETHUSDT_1d.csv...
  Chargement binance_public_data/BNBUSDT_1d.csv...
  Chargement binance_public_data/SOLUSDT_1d.csv...
  Chargement binance_public_data/XRPUSDT_1d.csv...
Période: 2021-01-02 00:00:00 → 2024-12-31 00:00:00 (1460 jours)

2. Calcul volatilité...

4. Backtest...

================================================================================
RÉSULTATS
================================================================================
Return annualisé: 29.32%
Vol annualisée:   69.62%
Sharpe:           0.727
Max Drawdown:     -84.15%
Turnover moyen:   3.06%

================================================================================
RUNNING STRATEGY: low_vol
================================================================================
================================================================================
PORTFOLIO STRATEGY: low_vol
================================================================================

1. Chargement des données...
  Chargement binance_public_data/BTCUSDT_1d.csv...
  Chargement binance_public_data/ETHUSDT_1d.csv...
  Chargement binance_public_data/BNBUSDT_1d.csv...
  Chargement binance_public_data/SOLUSDT_1d.csv...
  Chargement binance_public_data/XRPUSDT_1d.csv...
Période: 2021-01-02 00:00:00 → 2024-12-31 00:00:00 (1460 jours)

2. Calcul volatilité...

4. Backtest...

================================================================================
RÉSULTATS
================================================================================
Return annualisé: 27.74%
Vol annualisée:   67.52%
Sharpe:           0.708
Max Drawdown:     -81.45%
Turnover moyen:   6.78%

================================================================================
RUNNING STRATEGY: ml_stress
================================================================================
================================================================================
PORTFOLIO STRATEGY: ml_stress
================================================================================

1. Chargement des données...
  Chargement binance_public_data/BTCUSDT_1d.csv...
  Chargement binance_public_data/ETHUSDT_1d.csv...
  Chargement binance_public_data/BNBUSDT_1d.csv...
  Chargement binance_public_data/SOLUSDT_1d.csv...
  Chargement binance_public_data/XRPUSDT_1d.csv...
Période: 2021-01-02 00:00:00 → 2024-12-31 00:00:00 (1460 jours)

2. Calcul volatilité...

3. Entraînement modèles ML...
Stress AUC test: 0.9523
Avg gate: 0.880, Min: 0.200

4. Backtest...

================================================================================
RÉSULTATS
================================================================================
Return annualisé: 27.74%
Vol annualisée:   67.52%
Sharpe:           0.708
Max Drawdown:     -81.45%
Turnover moyen:   6.78%

================================================================================
RUNNING STRATEGY: ml_combined
================================================================================
================================================================================
PORTFOLIO STRATEGY: ml_combined
================================================================================

1. Chargement des données...
  Chargement binance_public_data/BTCUSDT_1d.csv...
  Chargement binance_public_data/ETHUSDT_1d.csv...
  Chargement binance_public_data/BNBUSDT_1d.csv...
  Chargement binance_public_data/SOLUSDT_1d.csv...
  Chargement binance_public_data/XRPUSDT_1d.csv...
Période: 2021-01-02 00:00:00 → 2024-12-31 00:00:00 (1460 jours)

2. Calcul volatilité...

3. Entraînement modèles ML...
Stress AUC test: 0.9523
Direction AUC test: 0.5139
Avg gate: 0.936, Min: 0.200

4. Backtest...

================================================================================
RÉSULTATS
================================================================================
Return annualisé: 27.74%
Vol annualisée:   67.52%
Sharpe:           0.708
Max Drawdown:     -81.45%
Turnover moyen:   6.78%

================================================================================
RÉSUMÉ COMPARATIF
================================================================================

               ann_return  ann_vol  sharpe  max_dd  turnover_mean
equal_weight      0.3901   0.7474  0.8252 -0.8694         0.0007
inverse_vol       0.2932   0.6962  0.7269 -0.8415         0.0306
low_vol           0.2774   0.6752  0.7080 -0.8145         0.0678
ml_stress         0.2774   0.6752  0.7080 -0.8145         0.0678
ml_combined       0.2774   0.6752  0.7080 -0.8145         0.0678
(base) PS C:\Users\HP\Documents\M2-222\M2 - 222 - S1\Python\Projet-Python-crypto>
